# %%
from kivy.app import App
from kivy.uix.widget import Widget
from kivy.graphics import Line, Color
from kivy.config import Config
from kivy.utils import get_color_from_hex
from kivy.uix.togglebutton import ToggleButton, ToggleButtonBehavior


class RadioButton(ToggleButton):
    def _do_press(self):
        if self.state == 'normal':
            # ToggleButtonBehavior._do_press(self)
            super()._do_press()


class CanvasWidget(Widget):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.color = get_color_from_hex('#2980B9')
        self.line_width = 2

    def on_touch_down(self, touch):
        if super().on_touch_down(touch):
            return
        with self.canvas:
            Color(*self.color)
            touch.ud['current_line'] = Line(points=(touch.x, touch.y), width=self.line_width)

    def on_touch_move(self, touch):
        try:
            touch.ud['current_line'].points += (touch.x, touch.y)
        except KeyError:
            pass

    def set_line_width(self, line_width=2):
        self.line_width = line_width

    def set_color(self, color):
        self.color = color

    def clear_canvas(self):
        saved_widgets = self.children[:]
        self.clear_widgets()
        self.canvas.clear()
        for widget in saved_widgets:
            self.add_widget(widget)


class PaintApp(App):
    def build(self):
        canvas_widget = CanvasWidget()
        # canvas_widget.set_color(get_color_from_hex('#2980B9'))
        # canvas_widget.set_line_width()
        return canvas_widget


if __name__ == '__main__':
    Config.set('graphics', 'width', '960')
    Config.set('graphics', 'height', '540')
    # Config.set('input', 'mouse', 'mouse,disable_multitouch')
    from kivy.core.window import Window

    Window.clearcolor = get_color_from_hex('#FFFFFF')
    PaintApp().run()
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\user\.kivy\logs\kivy_20-05-02_35.txt
# [INFO   ] [deps        ] Successfully imported "kivy_deps.glew" 0.2.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.sdl2" 0.2.0
# [INFO   ] [Kivy        ] v1.11.1
# [INFO   ] [Kivy        ] Installed at "C:\Users\user\Anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\user\Anaconda3\python.exe"
# [INFO   ] [Factory     ] 184 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil, img_gif (img_ffpyplayer ignored)
# [ERROR  ]
# Traceback (most recent call last):
#   File "C:\Users\user\Anaconda3\lib\site-packages\kivy\lang\parser.py", line 471, in execute_directives
#     mod = __import__(package)
# ModuleNotFoundError: No module named 'kivymd'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\user\Anaconda3\lib\site-packages\kivy\lang\parser.py", line 473, in execute_directives
#     mod = __import__('.'.join(package.split('.')[:-1]))
# ModuleNotFoundError: No module named 'kivymd'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\kivy\lang\parser.py in execute_directives(self)
#     470                         try:
# --> 471                             mod = __import__(package)
#     472                         except ImportError:
#
# ModuleNotFoundError: No module named 'kivymd'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\kivy\lang\parser.py in execute_directives(self)
#     472                         except ImportError:
# --> 473                             mod = __import__('.'.join(package.split('.')[:-1]))
#     474                         # resolve the whole thing
#
# ModuleNotFoundError: No module named 'kivymd'
#
# During handling of the above exception, another exception occurred:
#
# ParserException                           Traceback (most recent call last)
# <ipython-input-1-29fdb9f10749> in <module>
#      19             # на собственые атрибуты и методы текущего виджета.
#      20             self.text = root.new_text_for_button
# ---> 21 ''')
#      22
#      23 class StartScreen(BoxLayout):
#
# ~\Anaconda3\lib\site-packages\kivy\lang\builder.py in load_string(self, string, **kwargs)
#     366         try:
#     367             # parse the string
# --> 368             parser = Parser(content=string, filename=fn)
#     369
#     370             # merge rules with our rules
#
# ~\Anaconda3\lib\site-packages\kivy\lang\parser.py in __init__(self, **kwargs)
#     399         if content is None:
#     400             raise ValueError('No content passed')
# --> 401         self.parse(content)
#     402
#     403     def execute_directives(self):
#
# ~\Anaconda3\lib\site-packages\kivy\lang\parser.py in parse(self, content)
#     505
#     506         # Execute directives
# --> 507         self.execute_directives()
#     508
#     509         # Get object from the first level
#
# ~\Anaconda3\lib\site-packages\kivy\lang\parser.py in execute_directives(self)
#     482                     raise ParserException(self, ln,
#     483                                           'Unable to import package %r' %
# --> 484                                           package)
#     485             else:
#     486                 raise ParserException(self, ln, 'Unknown directive')
#
# ParserException: Parser: File "<inline>", line 2:
# ...
#       1:
# >>    2:#: import MDFlatButton kivymd.button.MDFlatButton
#       3:
#       4:<StartScreen>
# ...
# Unable to import package 'kivymd.button.MDFlatButton'
