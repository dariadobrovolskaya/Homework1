# %%
from kivy.app import App 
from kivy.uix.boxlayout import BoxLayout
from kivy.uix.label import Label
from kivy.uix.slider import Slider
from kivy.config import Config
from kivy.uix.widget import Widget
from kivy.graphics import Rectangle, Color, Line

Config.set('graphics', 'fullscreen', 'auto')
from random import random

from kivy.lang import Builder
Builder.load_string('''<Interface>:
    orientation: 'vertical'
    DrawingWidget:
    Slider:
        min: 0
        max: 1
        value: 0.5
        size_hint_y: None
        height: 50
    Slider:
        min: 0
        max: 1
        value: 0.5
        size_hint_y: None
        height: 50
    Slider:
        min: 0
        max: 1
        value: 0.5
        size_hint_y: None
        height: 50
    BoxLayout:
        orientation: 'horizontal'
        size_hint_y: None
        height: 50
        Label:
            text: 'output colour:'
        Widget:
''')
class DrawingWidget(Widget):
    def __init__(self):
        super(DrawingWidget, self).__init__()

        with self.canvas:
            Color(1, 1, 1, 1)
            self.rect = Rectangle(size=self.size,
                                  pos=self.pos)
        self.bind(pos=self.update_rectangle,
                  size=self.update_rectangle)

    def update_rectangle(self, instance, value):
        self.rect.pos = self.pos
        self.rect.size = self.size

    def on_touch_down(self, touch):
        super(DrawingWidget, self).on_touch_down(touch)

        if not self.collide_point(*touch.pos):
            return

        with self.canvas:
            Color(random(), random(), random())
            self.line = Line(points=[touch.pos[0], touch.pos[1]], width=2)

    def on_touch_move(self, touch):
        if not self.collide_point(*touch.pos):
            return

        self.line.points = self.line.points + [touch.pos[0], touch.pos[1]]


class Interface(BoxLayout):
    pass

class DrawingApp(App):

    def build(self):
        root_widget = Interface()
        return root_widget

DrawingApp().run()
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\user\.kivy\logs\kivy_20-05-02_34.txt
# [INFO   ] [deps        ] Successfully imported "kivy_deps.glew" 0.2.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.sdl2" 0.2.0
# [INFO   ] [Kivy        ] v1.11.1
# [INFO   ] [Kivy        ] Installed at "C:\Users\user\Anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\user\Anaconda3\python.exe"
# [INFO   ] [Factory     ] 184 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil, img_gif (img_ffpyplayer ignored)
# [INFO   ] [Text        ] Provider: sdl2
# ---------------------------------------------------------------------------
# ParserException                           Traceback (most recent call last)
# <ipython-input-1-42dd7dc6b0c6> in <module>
#      81         return root_widget
#      82
# ---> 83 DrawingApp().run()
#
# ~\Anaconda3\lib\site-packages\kivy\app.py in run(self)
#     826         if not self.built:
#     827             self.load_config()
# --> 828             self.load_kv(filename=self.kv_file)
#     829             root = self.build()
#     830             if root:
#
# ~\Anaconda3\lib\site-packages\kivy\app.py in load_kv(self, filename)
#     597             Logger.debug('App: kv <%s> not found' % filename)
#     598             return False
# --> 599         root = Builder.load_file(rfilename)
#     600         if root:
#     601             self.root = root
#
# ~\Anaconda3\lib\site-packages\kivy\lang\builder.py in load_file(self, filename, **kwargs)
#     299                     data = data[len(codecs.BOM_UTF8):]
#     300
# --> 301             return self.load_string(data, **kwargs)
#     302
#     303     def unload_file(self, filename):
#
# ~\Anaconda3\lib\site-packages\kivy\lang\builder.py in load_string(self, string, **kwargs)
#     366         try:
#     367             # parse the string
# --> 368             parser = Parser(content=string, filename=fn)
#     369
#     370             # merge rules with our rules
#
# ~\Anaconda3\lib\site-packages\kivy\lang\parser.py in __init__(self, **kwargs)
#     399         if content is None:
#     400             raise ValueError('No content passed')
# --> 401         self.parse(content)
#     402
#     403     def execute_directives(self):
#
# ~\Anaconda3\lib\site-packages\kivy\lang\parser.py in parse(self, content)
#     508
#     509         # Get object from the first level
# --> 510         objects, remaining_lines = self.parse_level(0, lines)
#     511
#     512         # Precompile rules tree
#
# ~\Anaconda3\lib\site-packages\kivy\lang\parser.py in parse_level(self, level, lines, spaces)
#     622                         if not all(ord(z) in Parser.PROP_RANGE for z in name):
#     623                             raise ParserException(self, ln,
# --> 624                                                   'Invalid property name')
#     625                     if len(x) == 1:
#     626                         raise ParserException(self, ln, 'Syntax error')
#
# ParserException: Parser: File "C:\Users\user\Desktop\HW1\drawing.kv", line 2:
# ...
#       1:{
# >>    2: "cells": [
#       3:  {
#       4:   "cell_type": "code",
# ...
# Invalid property name
